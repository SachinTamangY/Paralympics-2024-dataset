# %%
# Importing Libraries and data from kaggle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_medal_table = pd.read_csv('/Users/sachintamangyonjan/Downloads/Paralympics 2024 dataset/paralympics_2024_medal_table.csv')
df_medal_winners = pd.read_csv('/Users/sachintamangyonjan/Downloads/Paralympics 2024 dataset/paralympics_2024_medal_winners.csv')

# %%
df_medal_table.head(10)  # Top 10 medal winning countries
# Out:
#   Rank                      Country  Gold  Silver  Bronze  Total
# 0    1                        China    94      76      50    220
# 1    2                Great Britain    49      44      31    124
# 2    3                United States    36      42      27    105
# 3    4                  Netherlands    27      17      12     56
# 4    –  Neutral Paralympic Athletes    26      22      23     71
# 5    5                       Brazil    25      26      38     89
# 6    6                        Italy    24      15      32     71
# 7    7                      Ukraine    22      28      32     82
# 8    8                       France    19      28      28     75
# 9    9                    Australia    18      17      28     63

# %%
df_medal_winners.head(10)
# Out:
#        Sport                       Event        Category Class  \
# 0    Archery           Individualdetails    Men's events    W1
# 1    Archery  Individual compounddetails    Men's events  Open
# 2    Archery           Individualdetails  Women's events    W1
# 3    Archery  Individual compounddetails  Women's events  Open
# 4    Archery                 Teamdetails    Mixed events    W1
# 5    Archery        Team compounddetails    Mixed events  Open
# 6  Athletics           100 metresdetails    Men's events   T11
# 7  Athletics           200 metresdetails    Men's events   T35
# 8  Athletics           400 metresdetails    Men's events   T11
# 9  Athletics           800 metresdetails    Men's events   T34
#
#                                         Gold  \
# 0               Jason Tabansky United States
# 1                Matt Stutzman United States
# 2                           Chen Minyi China
# 3                          Öznur Cüre Turkey
# 4               ChinaChen MinyiZhang Tianxin
# 5  Great BritainJodie GrinhamNathan MacQueen
# 6                 Athanasios Ghavelas Greece
# 7                      Ihor Tsvietov Ukraine
# 8  Enderson German Santos Gonzalez Venezuela
# 9                       Austin Smeenk Canada
#
#                                           Silver  \
# 0                               Han Guifei China
# 1                              Ai Xinliang China
# 2                  Šárka Musilová Czech Republic
# 3                           Fatemeh Hemmati Iran
# 4  Czech RepublicŠárka MusilováDavid Drahonínský
# 5                   IranFatemeh HemmatiHadi Nori
# 6                        Timothee Adolphe France
# 7   Dmitrii Safronov Neutral Paralympic Athletes
# 8                        Timothée Adolphe France
# 9                       Chaiwat Rattana Thailand
#
#                                               Bronze
# 0                                Zhang Tianxin China
# 1                                     He Zihao China
# 2                   Tereza Brandtlová Czech Republic
# 3                        Jodie Grinham Great Britain
# 4                       ItalyDaila DamenoPaolo Tonon
# 5                      IndiaRakesh KumarSheetal Devi
# 6                                  Di Dongdong China
# 7        Artem Kalashian Neutral Paralympic Athletes
# 8  Guillaume Junior Atangana Refugee Paralympic Team
# 9                          Rheed McCracken Australia

# %%
# Data Cleaning and Data Wrangling
## 
print(df_medal_table.isnull().sum())
print(df_medal_winners.isnull().sum())
# Out:
# Rank       0
# Country    0
# Gold       0
# Silver     0
# Bronze     0
# Total      0
# dtype: int64
# Sport       0
# Event       0
# Category    0
# Class       0
# Gold        0
# Silver      0
# Bronze      0
# dtype: int64

# %%
# Bar graph for top 5 countries with thier medal tallies
import matplotlib.ticker as mticker
df_medal_table = df_medal_table.drop(index= 4)
df_medal_table = df_medal_table.set_index(['Country'])
df_medal_table.head(6).plot(kind='bar')
plt.title('Top 5 Countries and their medal tallies')
plt.xlabel('Countries')
plt.ylabel('Count of medals')
plt.xticks(rotation = 45)
plt.show()

# %%
# Medal distribution by sport
df_plot = df_medal_winners['Sport'].value_counts()
bar_plot = sns.barplot(y = df_plot.index, x = df_plot.values, palette= 'dark', hue= df_plot.index, legend= False)

plt.title("Medal Distribution by Sport")
plt.ylabel('Number of Medals')

# Adding value labels to bars
for p in bar_plot.patches:
    bar_plot.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height()/2),
                      ha = 'center', va = 'center', color = 'white', fontsize = 10, weight = 'bold')
plt.tight_layout()
plt.show()
